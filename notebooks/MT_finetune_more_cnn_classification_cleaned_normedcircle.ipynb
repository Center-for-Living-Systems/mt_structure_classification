# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
import torchvision.models as models
import pandas as pd
import os
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from torch.utils.data import Dataset, DataLoader
from PIL import Image
import tifffile
import numpy as np

# %%
# Check for GPU
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
# Set device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Load CSV
data_csv = "/mnt/d/lding/CLS/mousumiLiuDinner/selected_for_annotation_mt_strcture_20250310_MA.csv"
image_dir = "/mnt/d/lding/CLS/mousumiLiuDinner/set1to5_processed_results/" \
    "Microtubule_GUV-Liu-20250106T211105Z-001/processed_GUV_MT/" \
    "from_annotation_to_circle_square_edge/MT_rescaled_circle_crop_tiff"

df = pd.read_csv(data_csv)

for index, row in df.iterrows():
    index_select = int(row['filename'][-8:-4])
    
    if index_select in [18,21,328,480,356,543,669,78,242,726,762,771,812,977,983]:
        df.iloc[index]['label'] = 'poor'

df = df[df['label'] != 'poor']


df = df.dropna(subset=["filename", "label"])
df["label"] = df["label"].astype(str)

# Split into Train (80%) & Validation (20%)
train_df, val_df = train_test_split(df, test_size=0.2, stratify=df["label"], random_state=42)

# Define Transforms
train_transform = transforms.Compose([
    transforms.Grayscale(num_output_channels=3),
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])

val_transform = transforms.Compose([
    transforms.Grayscale(num_output_channels=3),
    transforms.Resize((224, 224)),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])

# Custom Dataset Class
class CustomDataset(Dataset):
    def __init__(self, dataframe, root_dir, transform=None):
        self.data = dataframe.copy()
        self.root_dir = root_dir
        self.transform = transform
        self.label_to_index = {label: idx for idx, label in enumerate(sorted(self.data["label"].unique()))}
        self.data["label"] = self.data["label"].map(self.label_to_index)
    
    def __len__(self):
        return len(self.data)
    
    def __getitem__(self, idx):
        # img_name = os.path.join(self.root_dir, self.data.iloc[idx, 0])
        # image = Image.open(img_name).convert("RGB")

        img_name = os.path.join(self.root_dir, self.data.iloc[idx, 0]).replace('png','tif')
        np_image = tifffile.imread(img_name)
        
        # Normalize or ensure correct dtype (uint8)
        if np_image.dtype != 'uint8':
            np_image = (255 * (np_image / np_image.max())).astype('uint8')
        
        # Convert grayscale/single channel to RGB if needed
        if np_image.ndim == 2:  # grayscale
            np_image = np.stack([np_image]*3, axis=-1)  # H x W x 3

        image = Image.fromarray(np_image) 

        label = int(self.data.iloc[idx, 1])
        if self.transform:
            image = self.transform(image)
        return image, label

# Create Datasets & DataLoaders
train_dataset = CustomDataset(train_df, image_dir, transform=train_transform)
val_dataset = CustomDataset(val_df, image_dir, transform=val_transform)
train_dataloader = DataLoader(train_dataset, batch_size=32, shuffle=True)
val_dataloader = DataLoader(val_dataset, batch_size=32, shuffle=False)
# Out:
# /tmp/ipykernel_514947/1942845152.py:16: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df.iloc[index]['label'] = 'poor'

# %%
# Load EfficientNet-B0 Model & Modify for Classification
from torchvision.models import efficientnet_b0

model = efficientnet_b0(pretrained=True)
num_ftrs = model.classifier[1].in_features
model.classifier[1] = nn.Sequential(
    nn.Dropout(0.3),  # Add dropout to reduce overfitting
    nn.Linear(num_ftrs, len(train_dataset.label_to_index))
)
model = model.to(device)

# Define Focal Loss for better handling of class imbalance
class FocalLoss(nn.Module):
    def __init__(self, alpha=1, gamma=2):
        super(FocalLoss, self).__init__()
        self.alpha = alpha
        self.gamma = gamma
        self.ce_loss = nn.CrossEntropyLoss()

    def forward(self, inputs, targets):
        ce_loss = self.ce_loss(inputs, targets)
        pt = torch.exp(-ce_loss)  # Probability of correct class
        focal_loss = self.alpha * (1 - pt) ** self.gamma * ce_loss
        return focal_loss.mean()

criterion = FocalLoss(alpha=1, gamma=2)

# Use AdamW optimizer with weight decay for better generalization
optimizer = optim.AdamW(model.parameters(), lr=0.0003, weight_decay=1e-4)

# Learning rate scheduler to adjust learning rate dynamically
scheduler = optim.lr_scheduler.CosineAnnealingLR(optimizer, T_max=20, eta_min=1e-6)

# Training Loop with Early Stopping
num_epochs = 200
best_val_acc = 0
patience = 30
patience_counter = 0
train_losses, val_losses, train_accuracies, val_accuracies = [], [], [], []

for epoch in range(num_epochs):
    model.train()
    running_loss, correct_train, total_train = 0.0, 0, 0
    
    for images, labels in train_dataloader:
        images, labels = images.to(device), labels.to(device)
        optimizer.zero_grad()
        outputs = model(images)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        running_loss += loss.item()
        _, preds = torch.max(outputs, 1)
        correct_train += (preds == labels).sum().item()
        total_train += labels.size(0)
    # print(correct_train)
    # print(total_train)
    train_loss = running_loss / len(train_dataloader)
    train_acc = correct_train / total_train
    
    # Validation Step
    model.eval()
    running_val_loss, correct_val, total_val = 0.0, 0, 0
    
    with torch.no_grad():
        for images, labels in val_dataloader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            loss = criterion(outputs, labels)
            running_val_loss += loss.item()
            _, preds = torch.max(outputs, 1)
            correct_val += (preds == labels).sum().item()
            total_val += labels.size(0)
    
    val_loss = running_val_loss / len(val_dataloader)
    val_acc = correct_val / total_val
    # print(correct_val)
    # print(total_val)
    
    train_losses.append(train_loss)
    val_losses.append(val_loss)
    train_accuracies.append(train_acc)
    val_accuracies.append(val_acc)
    
    print(f"Epoch {epoch+1}: Train Loss = {train_loss:.4f}, Train Acc = {train_acc:.4f}, Val Loss = {val_loss:.4f}, Val Acc = {val_acc:.4f}")
    
    scheduler.step()  # Adjust learning rate
    
    # Early Stopping
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        patience_counter = 0
        torch.save(model.state_dict(), "cleanning_version_normedcircle_best_model.pth")
    else:
        patience_counter += 1
        if patience_counter >= patience:
            print("Early stopping triggered. Best Validation Accuracy:", best_val_acc)
            break
# Out:
# /home/ldin/.local/lib/python3.10/site-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /home/ldin/.local/lib/python3.10/site-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=EfficientNet_B0_Weights.IMAGENET1K_V1`. You can also use `weights=EfficientNet_B0_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# Epoch 1: Train Loss = 0.8370, Train Acc = 0.3704, Val Loss = 0.9927, Val Acc = 0.2647
# Epoch 2: Train Loss = 0.3655, Train Acc = 0.7000, Val Loss = 0.9362, Val Acc = 0.3529
# Epoch 3: Train Loss = 0.1730, Train Acc = 0.8037, Val Loss = 0.8551, Val Acc = 0.3382
# Epoch 4: Train Loss = 0.1017, Train Acc = 0.8444, Val Loss = 0.4622, Val Acc = 0.6471
# Epoch 5: Train Loss = 0.0733, Train Acc = 0.8630, Val Loss = 0.2903, Val Acc = 0.6765
# Epoch 6: Train Loss = 0.0248, Train Acc = 0.9370, Val Loss = 0.2378, Val Acc = 0.6765
# Epoch 7: Train Loss = 0.0197, Train Acc = 0.9296, Val Loss = 0.2218, Val Acc = 0.6765
# Epoch 8: Train Loss = 0.0246, Train Acc = 0.9185, Val Loss = 0.2077, Val Acc = 0.6912
# Epoch 9: Train Loss = 0.0149, Train Acc = 0.9444, Val Loss = 0.2358, Val Acc = 0.6324
# Epoch 10: Train Loss = 0.0110, Train Acc = 0.9593, Val Loss = 0.2353, Val Acc = 0.6471
# Epoch 11: Train Loss = 0.0077, Train Acc = 0.9778, Val Loss = 0.2352, Val Acc = 0.6765
# Epoch 12: Train Loss = 0.0085, Train Acc = 0.9704, Val Loss = 0.2394, Val Acc = 0.6618
# Epoch 13: Train Loss = 0.0097, Train Acc = 0.9704, Val Loss = 0.2343, Val Acc = 0.6618
# Epoch 14: Train Loss = 0.0071, Train Acc = 0.9704, Val Loss = 0.2372, Val Acc = 0.6912
# Epoch 15: Train Loss = 0.0049, Train Acc = 0.9852, Val Loss = 0.2336, Val Acc = 0.6912
# Epoch 16: Train Loss = 0.0054, Train Acc = 0.9741, Val Loss = 0.2365, Val Acc = 0.6912
# Epoch 17: Train Loss = 0.0062, Train Acc = 0.9889, Val Loss = 0.2306, Val Acc = 0.6618
# Epoch 18: Train Loss = 0.0060, Train Acc = 0.9778, Val Loss = 0.2347, Val Acc = 0.6912
# Epoch 19: Train Loss = 0.0059, Train Acc = 0.9741, Val Loss = 0.2343, Val Acc = 0.6912
# Epoch 20: Train Loss = 0.0067, Train Acc = 0.9741, Val Loss = 0.2411, Val Acc = 0.6912
# Epoch 21: Train Loss = 0.0043, Train Acc = 0.9815, Val Loss = 0.2390, Val Acc = 0.6912
# Epoch 22: Train Loss = 0.0058, Train Acc = 0.9667, Val Loss = 0.2457, Val Acc = 0.6618
# Epoch 23: Train Loss = 0.0067, Train Acc = 0.9778, Val Loss = 0.2363, Val Acc = 0.6912
# Epoch 24: Train Loss = 0.0043, Train Acc = 0.9889, Val Loss = 0.2318, Val Acc = 0.6912
# Epoch 25: Train Loss = 0.0065, Train Acc = 0.9852, Val Loss = 0.2393, Val Acc = 0.6912
# Epoch 26: Train Loss = 0.0057, Train Acc = 0.9704, Val Loss = 0.2328, Val Acc = 0.6912
# Epoch 27: Train Loss = 0.0107, Train Acc = 0.9593, Val Loss = 0.2347, Val Acc = 0.6912
# Epoch 28: Train Loss = 0.0086, Train Acc = 0.9704, Val Loss = 0.2281, Val Acc = 0.6618
# Epoch 29: Train Loss = 0.0034, Train Acc = 0.9852, Val Loss = 0.2254, Val Acc = 0.6912
# Epoch 30: Train Loss = 0.0088, Train Acc = 0.9667, Val Loss = 0.2318, Val Acc = 0.7059
# Epoch 31: Train Loss = 0.0058, Train Acc = 0.9778, Val Loss = 0.2388, Val Acc = 0.6912
# Epoch 32: Train Loss = 0.0032, Train Acc = 0.9852, Val Loss = 0.2362, Val Acc = 0.6765
# Epoch 33: Train Loss = 0.0038, Train Acc = 0.9778, Val Loss = 0.2282, Val Acc = 0.6912
# Epoch 34: Train Loss = 0.0022, Train Acc = 0.9963, Val Loss = 0.2328, Val Acc = 0.6618
# Epoch 35: Train Loss = 0.0036, Train Acc = 0.9852, Val Loss = 0.2436, Val Acc = 0.6471
# Epoch 36: Train Loss = 0.0036, Train Acc = 0.9667, Val Loss = 0.2524, Val Acc = 0.6471
# Epoch 37: Train Loss = 0.0020, Train Acc = 0.9926, Val Loss = 0.2317, Val Acc = 0.6765
# Epoch 38: Train Loss = 0.0014, Train Acc = 0.9889, Val Loss = 0.2175, Val Acc = 0.7059
# Epoch 39: Train Loss = 0.0014, Train Acc = 0.9926, Val Loss = 0.2132, Val Acc = 0.7206
# Epoch 40: Train Loss = 0.0012, Train Acc = 0.9852, Val Loss = 0.2260, Val Acc = 0.7059
# Epoch 41: Train Loss = 0.0024, Train Acc = 0.9741, Val Loss = 0.2332, Val Acc = 0.7059
# Epoch 42: Train Loss = 0.0008, Train Acc = 0.9926, Val Loss = 0.2186, Val Acc = 0.7206
# Epoch 43: Train Loss = 0.0003, Train Acc = 1.0000, Val Loss = 0.2101, Val Acc = 0.7059
# Epoch 44: Train Loss = 0.0009, Train Acc = 0.9889, Val Loss = 0.2211, Val Acc = 0.6765
# Epoch 45: Train Loss = 0.0020, Train Acc = 0.9926, Val Loss = 0.2100, Val Acc = 0.7206
# Epoch 46: Train Loss = 0.0006, Train Acc = 0.9926, Val Loss = 0.2824, Val Acc = 0.6324
# Epoch 47: Train Loss = 0.0014, Train Acc = 0.9889, Val Loss = 0.2679, Val Acc = 0.6618
# Epoch 48: Train Loss = 0.0028, Train Acc = 0.9889, Val Loss = 0.2745, Val Acc = 0.6471
# Epoch 49: Train Loss = 0.0006, Train Acc = 0.9926, Val Loss = 0.2566, Val Acc = 0.6176
# Epoch 50: Train Loss = 0.0065, Train Acc = 0.9926, Val Loss = 0.2419, Val Acc = 0.6324
# Epoch 51: Train Loss = 0.0008, Train Acc = 0.9963, Val Loss = 0.3420, Val Acc = 0.5735
# Epoch 52: Train Loss = 0.0029, Train Acc = 0.9667, Val Loss = 0.3312, Val Acc = 0.5588
# Epoch 53: Train Loss = 0.0016, Train Acc = 0.9778, Val Loss = 0.2891, Val Acc = 0.5735
# Epoch 54: Train Loss = 0.0025, Train Acc = 0.9852, Val Loss = 0.2582, Val Acc = 0.6029
# Epoch 55: Train Loss = 0.0006, Train Acc = 0.9889, Val Loss = 0.2419, Val Acc = 0.6029
# Epoch 56: Train Loss = 0.0004, Train Acc = 0.9963, Val Loss = 0.2468, Val Acc = 0.6029
# Epoch 57: Train Loss = 0.0006, Train Acc = 0.9963, Val Loss = 0.2444, Val Acc = 0.5882
# Epoch 58: Train Loss = 0.0010, Train Acc = 0.9963, Val Loss = 0.2484, Val Acc = 0.6029
# Epoch 59: Train Loss = 0.0010, Train Acc = 0.9889, Val Loss = 0.2427, Val Acc = 0.5882
# Epoch 60: Train Loss = 0.0017, Train Acc = 0.9926, Val Loss = 0.2325, Val Acc = 0.6324
# Epoch 61: Train Loss = 0.0010, Train Acc = 0.9889, Val Loss = 0.2358, Val Acc = 0.6176
# Epoch 62: Train Loss = 0.0014, Train Acc = 0.9778, Val Loss = 0.2382, Val Acc = 0.6029
# Epoch 63: Train Loss = 0.0002, Train Acc = 1.0000, Val Loss = 0.2357, Val Acc = 0.5882
# Epoch 64: Train Loss = 0.0010, Train Acc = 0.9963, Val Loss = 0.2197, Val Acc = 0.6029
# Epoch 65: Train Loss = 0.0005, Train Acc = 0.9963, Val Loss = 0.2360, Val Acc = 0.5735
# Epoch 66: Train Loss = 0.0012, Train Acc = 0.9815, Val Loss = 0.2311, Val Acc = 0.6029
# Epoch 67: Train Loss = 0.0004, Train Acc = 1.0000, Val Loss = 0.2162, Val Acc = 0.6324
# Epoch 68: Train Loss = 0.0007, Train Acc = 0.9963, Val Loss = 0.2206, Val Acc = 0.6029
# Epoch 69: Train Loss = 0.0012, Train Acc = 1.0000, Val Loss = 0.2067, Val Acc = 0.6029
# Early stopping triggered. Best Validation Accuracy: 0.7205882352941176

# %%
import matplotlib
plt.rcParams['font.family'] = 'DejaVu Sans'
matplotlib.rcParams['font.size'] = 12

# Plot training and validation losses and accuracies
def plot_metrics(train_losses, val_losses, train_accuracies, val_accuracies):
    plt.figure(figsize=(12, 3),dpi=500)    
    plt.subplot(1, 2, 1)
    plt.plot(train_losses, label='Training Loss')
    plt.plot(val_losses, label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.title('Loss Curve')
    plt.legend()
    
    plt.subplot(1, 2, 2)
    plt.plot(train_accuracies, label='Training Accuracy')
    plt.plot(val_accuracies, label='Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy (%)')
    plt.title('Accuracy Curve')
    plt.legend()
    
    plt.show()
    
plot_metrics(train_losses, val_losses, train_accuracies, val_accuracies)

# %%
import numpy as np


model.load_state_dict(torch.load("cleanning_version_normedcircle_best_model.pth"))
    
# Function to evaluate model and plot confusion matrix with percentages
def evaluate_model(dataloader, dataset_name):
    true_labels, pred_labels = [], []
    model.eval()
    with torch.no_grad():
        for images, labels in dataloader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            _, preds = torch.max(outputs, 1)
            true_labels.extend(labels.cpu().numpy())
            pred_labels.extend(preds.cpu().numpy())
    
    cm = confusion_matrix(true_labels, pred_labels)
    cm_percentage = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis] * 100  # Convert to percentages
    labels = list(train_dataset.label_to_index.keys())
    cm_percent_df = pd.DataFrame(cm_percentage, index=labels, columns=labels)
    
    cm_df = pd.DataFrame(cm, index=labels, columns=labels)
    
    plt.figure(figsize=(8, 6))
    sns.heatmap(cm_df, annot=True, fmt="d", cmap="Blues", linewidths=0.5)
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.title(f"Confusion Matrix ({dataset_name})")
    plt.show()

    plt.figure(figsize=(8, 6))
    sns.heatmap(cm_percent_df, annot=True, fmt=".1f", cmap="Blues", linewidths=0.5)
    plt.xlabel("Predicted")
    plt.ylabel("Actual")
    plt.title(f"Confusion Matrix ({dataset_name}) - Percentage")
    plt.show()

evaluate_model(train_dataloader, "Training Set")
evaluate_model(val_dataloader, "Validation Set")
